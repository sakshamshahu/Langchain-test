# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import UnstructuredPDFLoader

# %%
loader = UnstructuredPDFLoader("/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf", mode = "elements")
data = loader.load()
print(data)
# Out:
# [Document(page_content='FUNDAMENTALS OF', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((461.0, 354.0), (461.0, 389.0), (903.0, 389.0), (903.0, 354.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 1, 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'Title'}), Document(page_content='Database Systems', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((459.0, 459.0), (459.0, 718.0), (1038.0, 718.0), (1038.0, 459.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 1, 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'Title'}), Document(page_content='SIXTH EDITION', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((459.0, 788.0), (459.0, 823.0), (785.0, 823.0), (785.0, 788.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 1, 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'Title'}), Document(page_content='Ramez Elmasri Department of Computer Science and Engineering The University of Texas at Arlington', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((458.0, 988.0), (458.0, 1115.0), (1165.0, 1115.0), (1165.0, 988.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 1, 'parent_id': '94057fbccb48bb9b5dce919cb2c67c21', 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'UncategorizedText'}), Document(page_content='Shamkant B. Navathe College of Computing Georgia Institute of Technology', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((458.0, 1171.0), (458.0, 1296.0), (894.0, 1296.0), (894.0, 1171.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 1, 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'Title'}), Document(page_content='Addison-Wesley Boston Columbus Indianapolis New York San Francisco Upper Saddle River Amsterdam Cape Town Dubai London Madrid Milan Munich Paris Montreal Toronto Delhi Mexico City Sao Paulo Sydney Hong Kong Seoul Singapore Taipei Tokyo', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((263.0, 1620.0), (263.0, 1743.0), (1152.0, 1743.0), (1152.0, 1620.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 1, 'parent_id': '07d282228e3b2a19d91c7e7abf86f10b', 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'UncategorizedText'}), Document(page_content='Addison-Wesley is an imprint of', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordi ...

# %%
data[1]
# Out:
# Document(page_content='Database Systems', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((459.0, 459.0), (459.0, 718.0), (1038.0, 718.0), (1038.0, 459.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 1, 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'Title'})

# %%
data[6]
# Out:
# Document(page_content='Addison-Wesley is an imprint of', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/30_pages_struct.pdf', 'coordinates': {'points': ((121.0, 1566.0), (121.0, 1643.0), (369.0, 1643.0), (369.0, 1566.0)), 'system': 'PixelSpace', 'layout_width': 1700, 'layout_height': 2200}, 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2024-02-06T15:28:55', 'page_number': 2, 'parent_id': '07d282228e3b2a19d91c7e7abf86f10b', 'file_directory': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data', 'filename': '30_pages_struct.pdf', 'category': 'NarrativeText'})

# %%
load = PyPDFLoader('/Users/saksham/Projects/Langchain-test/data/raw/sample_data/new-solution-to-the-midas-touch-problem-identification-of-visual-commands-via-extraction-of-focal-fixations.pdf')
page = load.load_and_split()

# %%
len(page)
# Out:
# 11

# %%
page[2]
# Out:
# Document(page_content='quick estimation of objects’ locations. This leads to high  amplitude saccades exceeding the parafoveal area (4 -5 \ndegrees) and s\nhort fixations which do not allow iden tification of objects. Focal perception allows object \nidentification. For object identification long fixations  on the object and low amplitude saccades not  leaving the \nparaf\noveal area are needed. The analysis of eye moveme nts makes it possible to determine the actually dominating \nmodus of visual perception in real -time.  \nIn a study of road situation analysis by Velichkovsky et al. (2002) three clusters of fixations were found: very \nsh\nort fixations preceded by high amplitude saccades (co rrecting fixations), fixations with duration between 90 and \n140 ms preceded by high amplitude saccades exceeding the size of parafoveal area (ambie nt fixations), and fixations \nwith durations over 140 -200 ms followed by saccades not exceeding the si ze of  parafoveal area (focal fixations). \nThese fixation clusters differ in duration: most of the correcting fixations lasts for about 60 ms, most of the ambient fixations lasts between  100 ms and 250 ms, and most of the focal fixations lasts are longer that 280 -300 ms. Similar \nclassi \nfication of fixations can be found for the perception of static scenes.', metadata={'source': '/Users/saksham/Projects/Langchain-test/data/raw/sample_data/new-solution-to-the-midas-touch-problem-identification-of-visual-commands-via-extraction-of-focal-fixations.pdf', 'page': 1})
